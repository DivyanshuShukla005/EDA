# %% [markdown]
# # Zomato Exploratory Data Analysis

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
# by putting matlplotlib inline we avoid using plt.show again n again

# %%
os.chdir("E:\data")

# %%
os.listdir()
# Out:
# ['act_pred_train.xlsx',
#  'bank.xlsx',
#  'Banks_full.csv',
#  'Bank_Account_Details.csv',
#  'BANK_ACCOUNT_TRANSACTION.csv',
#  'Bank_customer.csv',
#  'car data.csv',
#  'Car details v3.csv',
#  'car_done.csv',
#  'car_evaluation.csv',
#  'corr.xlsx',
#  'Country-Code.xlsx',
#  'Country-wise_India_Exports_by_Principal_Commodity_in_2011-12_And_2012-13.xls',
#  'country_wise_latest.csv',
#  'covid19_sample1.csv',
#  'Customer.csv',
#  'Customer.xlsx',
#  'Cust_data.csv',
#  'Cust_demo.csv',
#  'cust_new.csv',
#  'cust_seg.csv',
#  'Data.csv',
#  'data_time_series.csv',
#  'decision-tree-classifier-tutorial.ipynb',
#  'Default.csv',
#  'diabetes.csv',
#  'E Commerce Dataset.xlsx',
#  'Ecommerce.csv',
#  'emp.xlsx',
#  'exported data.csv',
#  'Good study_projects',
#  'GoogleReview.csv',
#  'google_review_ratings.csv',
#  'Groceries_dataset.csv',
#  'homework.xlsx',
#  'HR data.csv',
#  'https.docx',
#  'kc_house_data.csv',
#  'Laptop.csv',
#  'LoansData (1).csv',
#  'LoansData.csv',
# ...

# %%
zomato=pd.read_csv('zomato.csv',encoding="latin-1" )
# # utf-8(cant decode the file) error occur so,we use endocing latin-1 ffor read the file smoothly.
# different encoding for different error read pandas documentation for more

# %%
zomato.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                    Japanese  ...  Botswana Pula(P)               Yes
#
# ...

# %%
zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
zomato.shape
# Out:
# (9551, 21)

# %%
zomato.describe().T
# Out:
#                        count          mean           std         min  \
# Restaurant ID         9551.0  9.051128e+06  8.791521e+06   53.000000
# Country Code          9551.0  1.836562e+01  5.675055e+01    1.000000
# Longitude             9551.0  6.412657e+01  4.146706e+01 -157.948486
# Latitude              9551.0  2.585438e+01  1.100794e+01  -41.330428
# Average Cost for two  9551.0  1.199211e+03  1.612118e+04    0.000000
# Price range           9551.0  1.804837e+00  9.056088e-01    1.000000
# Aggregate rating      9551.0  2.666370e+00  1.516378e+00    0.000000
# Votes                 9551.0  1.569097e+02  4.301691e+02    0.000000
#
#                                 25%           50%           75%           max
# Restaurant ID         301962.500000  6.004089e+06  1.835229e+07  1.850065e+07
# Country Code               1.000000  1.000000e+00  1.000000e+00  2.160000e+02
# Longitude                 77.081343  7.719196e+01  7.728201e+01  1.748321e+02
# ...

# %%
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# # In data analysis we do
# 1.gernal info
#
# 2.finding missing value
#
# 3.explore numerical value like (visualization,pivots ,etc)
#
# 4.explore categorical value like (visualization,pivot,etc)
#
# 5.finding relationship (correlation or multicorelation)

# %%
zomato.isnull().sum()
# only cusine have 9 missing value
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[col for col in zomato.columns if zomato[col].isnull().sum()>0]
# this code writing is called line comprehension (code in one line)
# anotherway to find missing value
# Out:
# ['Cuisines']

# %%
sns.heatmap(zomato.isnull(),yticklabels=False , cbar=False ,cmap="viridis")
# graphical way to find out missing value
# missing values are small in camparision to dataset that's why we cant see them
# Out:
# <AxesSubplot:>

# %%
zomato.columns
# we have country code in both the tables so, we have to merge them into one.
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
concode=pd.read_excel("Country-Code.xlsx")

# %%
concode.head(2)
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia

# %%
crux=pd.merge(zomato,concode,on="Country Code",how="left")
# merging both table by country code(treated as primary key)is in both table
# putting left join (watch how)
# this is our final table 
#apply join according to need .

# %%
crux.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %%
crux.dtypes
# way to find out data types
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
crux.dtypes[crux.dtypes!='object']
# way to find out particuar data type
# Out:
# Restaurant ID             int64
# Country Code              int64
# Longitude               float64
# Latitude                float64
# Average Cost for two      int64
# Price range               int64
# Aggregate rating        float64
# Votes                     int64
# dtype: object

# %%
crux.dtypes[crux.dtypes=='object']
# way to find out particuar data type
# Out:
# Restaurant Name         object
# City                    object
# Address                 object
# Locality                object
# Locality Verbose        object
# Cuisines                object
# Currency                object
# Has Table booking       object
# Has Online delivery     object
# Is delivering now       object
# Switch to order menu    object
# Rating color            object
# Rating text             object
# Country                 object
# dtype: object

# %%
crux.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
crux.Country.value_counts()
# In this code we get country with name with values 
# im going to show in pie chart so segregate name and value in different variable
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
country_names=crux.Country.value_counts().index
# we stored country name in this variable

# %%
country_val=crux.Country.value_counts().values
# we store values  in this variable

# %%
plt.pie(country_val[:3],labels=country_names[:3],autopct='%1.2f%%')
# their are so many country so, we taake top 3 country ([:3])
# autopct stands for the percentage ('%1.2f%%'= means after decimal 2 number will come.)
# Out:
# ([<matplotlib.patches.Wedge at 0x27870ecb7f0>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %% [markdown]
# Observation : Zomato maximum record or transaction ar from india after that USA and then united kingdoms

# %%
crux.groupby(['Aggregate rating','Rating color','Rating text']).size()
# make a dataframe by doing group by function
# with size we see all the data which are store in these variables
# Out:
# Aggregate rating  Rating color  Rating text
# 0.0               White         Not rated      2148
# 1.8               Red           Poor              1
# 1.9               Red           Poor              2
# 2.0               Red           Poor              7
# 2.1               Red           Poor             15
# 2.2               Red           Poor             27
# 2.3               Red           Poor             47
# 2.4               Red           Poor             87
# 2.5               Orange        Average         110
# 2.6               Orange        Average         191
# 2.7               Orange        Average         250
# 2.8               Orange        Average         315
# 2.9               Orange        Average         381
# 3.0               Orange        Average         468
# 3.1               Orange        Average         519
# 3.2               Orange        Average         522
# 3.3               Orange        Average         483
# ...

# %%
ratings=crux.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:"Ratings Counts"})
# now we are resetting the index & renaming it like (where their is 0 in column name so,it will make Rating counts)
# we groupby all variables so, last rating counts column occurs it means (we have 2148 records for this => 0.0,white,not rated )
# at last we keep all this information into rating variable

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Ratings Counts
# 0                0.0        White   Not rated            2148
# 1                1.8          Red        Poor               1
# 2                1.9          Red        Poor               2
# 3                2.0          Red        Poor               7
# 4                2.1          Red        Poor              15
# 5                2.2          Red        Poor              27
# 6                2.3          Red        Poor              47
# 7                2.4          Red        Poor              87
# 8                2.5       Orange     Average             110
# 9                2.6       Orange     Average             191
# 10               2.7       Orange     Average             250
# 11               2.8       Orange     Average             315
# 12               2.9       Orange     Average             381
# 13               3.0       Orange     Average             468
# ...

# %% [markdown]
# ## Observation
# When Rating is between 4.5 to 4.9---> Excellent
#
# When Rating are between 4.0 to 4.4--->very good
#
# when Rating is between 3.5 to 3.9----> good
#
# when Rating is between 2.5 to 3.4----> average
#
# when Rating is between 1.8 to 2.4----> Poor

# %%
ratings.head(2)
# Out:
#    Aggregate rating Rating color Rating text  Ratings Counts
# 0               0.0        White   Not rated            2148
# 1               1.8          Red        Poor               1

# %%
import matplotlib
matplotlib.rcParams["figure.figsize"]=(12,6)
sns.barplot(x="Aggregate rating",y="Ratings Counts",data=ratings)
# we made barplot by using x-axis and y-axis with ratings variable
# we also increase the size of the diagram by using (rcparams)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Ratings Counts'>

# %%
sns.barplot(x="Aggregate rating",y="Ratings Counts",hue='Rating color',data=ratings,palette=['blue','red','orange','yellow','lightgreen','darkgreen'])
# in this we are giving the scale by using hue
# with the help of palette we are going to map the colour according to need (palette is used in bar ,count plots kinds)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Ratings Counts'>

# %% [markdown]
# **Observation**
#
# 1. Not Rated count is very high
# 2. Maximum number of rating are between 2.5 to 3.4

# %%
sns.countplot(x="Rating color",data=ratings,palette=['blue','red','orange','yellow','lightgreen','Darkgreen'])
# we are just count the rating variable with count plot 
# palette is used like above.
# we just use blue colour insted of useing white because it seems like invisible
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %% [markdown]
# **Observation Acoording to count plot**
# 1. white rating is minimum in count
# 2. orange rating is high in count
# 3. both green are similar in ratings

# %%
ratings 
# see white has one rating in count.
# Out:
#     Aggregate rating Rating color Rating text  Ratings Counts
# 0                0.0        White   Not rated            2148
# 1                1.8          Red        Poor               1
# 2                1.9          Red        Poor               2
# 3                2.0          Red        Poor               7
# 4                2.1          Red        Poor              15
# 5                2.2          Red        Poor              27
# 6                2.3          Red        Poor              47
# 7                2.4          Red        Poor              87
# 8                2.5       Orange     Average             110
# 9                2.6       Orange     Average             191
# 10               2.7       Orange     Average             250
# 11               2.8       Orange     Average             315
# 12               2.9       Orange     Average             381
# 13               3.0       Orange     Average             468
# ...

# %%
crux[crux['Rating color']=='White'].groupby('Country').size().reset_index().rename(columns={0:"white Ratings Counts"})
# we found ratings is white and groupby it with country
# size helps to get data inside it
# also rename column by white ratings
# Out:
#           Country  white Ratings Counts
# 0          Brazil                     5
# 1           India                  2139
# 2  United Kingdom                     1
# 3   United States                     3

# %%
crux.groupby(['Aggregate rating','Country']).size().reset_index().rename(columns={0:"Count"}).head(5)
# we just groupby both aggregate ratings and country variables 
# by this we easily know which country is giving how much rating
# Out:
#      Aggregate rating         Country  Count
# 0                 0.0          Brazil      5
# 1                 0.0           India   2139
# 2                 0.0  United Kingdom      1
# 3                 0.0   United States      3
# 4                 1.8           India      1
# ..                ...             ...    ...
# 217               4.9       Sri Lanka      1
# 218               4.9          Turkey      3
# 219               4.9             UAE      4
# 220               4.9  United Kingdom      4
# 221               4.9   United States     14
#
# [222 rows x 3 columns]

# %%
crux[['Country','Currency']].groupby(['Country','Currency']).size().reset_index().rename(columns={0:"country_wise_earnnings "})
# groupby currency and country this tells earnings from each country
# Out:
#            Country                Currency  country_wise_earnnings
# 0        Australia               Dollar($)                       24
# 1           Brazil      Brazilian Real(R$)                       60
# 2           Canada               Dollar($)                        4
# 3            India      Indian Rupees(Rs.)                     8652
# 4        Indonesia  Indonesian Rupiah(IDR)                       21
# 5      New Zealand           NewZealand($)                       40
# 6      Phillipines        Botswana Pula(P)                       22
# 7            Qatar         Qatari Rial(QR)                       20
# 8        Singapore               Dollar($)                       20
# 9     South Africa                 Rand(R)                       60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)                       20
# 11          Turkey        Turkish Lira(TL)                       34
# 12             UAE      Emirati Diram(AED)                       60
# ...

# %%
crux.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
crux[crux['Has Online delivery'] =="Yes"].Country.value_counts()
# By this we are going to know how many country has online delivery
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
crux[['Has Online delivery','Country']].groupby(['Has Online delivery','Country']).size().reset_index()
# Out:
#    Has Online delivery         Country     0
# 0                   No       Australia    24
# 1                   No          Brazil    60
# 2                   No          Canada     4
# 3                   No           India  6229
# 4                   No       Indonesia    21
# 5                   No     New Zealand    40
# 6                   No     Phillipines    22
# 7                   No           Qatar    20
# 8                   No       Singapore    20
# 9                   No    South Africa    60
# 10                  No       Sri Lanka    20
# 11                  No          Turkey    34
# 12                  No             UAE    32
# 13                  No  United Kingdom    80
# 14                  No   United States   434
# 15                 Yes           India  2423
# 16                 Yes             UAE    28

# %% [markdown]
# **Observation of has online delivery**
# 1. India and UAE only has onine delevery
# 2. But they are coming twice in list it means in some region they don,t has online delivery

# %%
crux.City.value_counts()
# In this code we get city with name with values 
# im going to show in pie chart so segregate name and value in different variable
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64

# %%
city_values=crux.City.value_counts().values
# we store values  in this variable

# %%
city_labels=crux.City.value_counts().index
# we store city name in this variable

# %%
plt.pie(city_values[:5],labels=city_labels[:5],autopct='%1.2f%%')
# their are so many cities so, we take top 5 city ([:5])
# autopct stands for the percentage ('%1.2f%%'= means after decimal 2 number will come.)
# Out:
# ([<matplotlib.patches.Wedge at 0x278749347f0>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31%')])
